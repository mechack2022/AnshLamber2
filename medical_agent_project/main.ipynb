# %%
from agent import medical_agent

if __name__ == "__main__":
    patient_id = "LAM67890"
    result = medical_agent(patient_id)
    print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from agent import medical_agent
#       3 if __name__ == "__main__":
#       4     patient_id = "LAM67890"
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/medical_agent_project/agent.py:1
# ----> 1 from tools import get_cd4_count, get_viral_load, recommend_regimen
#       2 from models import PatientData, LabResults
#       4 def medical_agent(patient_id: str) -> str:
#
# ImportError: cannot import name 'get_cd4_count' from 'tools' (/Users/MAC/Desktop/personal-project/Langchain/AnshLamber2/medical_agent_project/tools.py)
