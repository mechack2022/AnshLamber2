# %%
from agent import medical_agent

if __name__ == "__main__":
    patient_id = "LAM67890"
    result = medical_agent(patient_id)
    print(result)
# Out:
# Patient ID: LAM67890
# CD4 count: 280
# Viral load: 75000
# Recommendation: Consider switching to second-line regimen
