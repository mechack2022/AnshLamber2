# %% [markdown]
# """
# Exercise 1: Translation Chain
#
# Create a chain that:
# 1. Takes text and target language as input
# 2. Translates the text
# 3. Returns the translation
#
# Test with: "Hello, how are you?" → Spanish
# """
#
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from dotenv import load_dotenv
#
# load_dotenv()
#
# ### YOUR CODE HERE
# ### Create:
# ### 1. Prompt template with {text} and {language} variables
# ### 2. LLM instance
# ### 3. Output parser
# ### 4. Chain combining all three
#
# ### Test your chain
# ### result = chain.invoke({"text": "Hello, how are you?", "language": "Spanish"})
# print(result)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-5-mini", temperature=0)
langauge_translator = (
    ChatPromptTemplate.from_template(
     "You are a language translator, transform this text into {language} : {input}"
    ) | llm | StrOutputParser()
)

result = langauge_translator.invoke({
    "input":"Hello, how are you?",
    "language": "Yoruba"
})
print(result)
# Out:
# Sannu, ya kake? (idan magana ga mace: "Sannu, ya kike?")

# %% [markdown]
# </details>
#
# ---
#
# ## 🎯 Exercise 2: Sequential Chain (Intermediate)
#
# **Goal:** Chain two LLM calls together
#
# **Task:** Create a chain that generates a patient report and then summarizes it
# ```python
# """
# Exercise 2: Report Generation + Summarization Chain
#
# Step 1: Generate detailed patient report from symptoms
# Step 2: Summarize the report into key points
#
# Input: Patient symptoms
# Output: Summary of detailed report
# """
#
# # YOUR CODE HERE
# # Create:
# # 1. Chain 1: Generate detailed report from symptoms
# # 2. Chain 2: Summarize the report
# # 3. Combine them so output of chain 1 feeds into chain 2
#
# # Test data
# symptoms = "fever 38.5°C, persistent cough, fatigue, loss of appetite"
#
# # Test your chain
# result = full_chain.invoke({"symptoms": symptoms})
# print(result)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser


llm = ChatOpenAI(model="gpt-5-mini", temperature=0)

report_chain = (
      ChatPromptTemplate.from_template(
        "Generate a clinical report from these symptoms: {symptoms}"
      ) 
      | llm 
      | StrOutputParser()
)

summarization_chain = (
     ChatPromptTemplate.from_template(
      "Summarize this clinical report as an expert physician : {report}"
     ) | llm |StrOutputParser
)

combine_chain = {"report" : report_chain } | summarization_chain
symptoms = "fever 38.5°C, persistent cough, fatigue, loss of appetite"
result = combine_chain.invoke({"symptoms": symptoms})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 22
#      20 combine_chain = {"report" : report_chain } | summarization_chain
#      21 symptoms = "fever 38.5°C, persistent cough, fatigue, loss of appetite"
# ---> 22 result = combine_chain.invoke({"symptoms": symptoms})
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3151, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3149                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3150             else:
# -> 3151                 input_ = context.run(step.invoke, input_, config)
#    3152 # finish the root run
#    3153 except BaseException as e:
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:4880, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4865 """Invoke this `Runnable` synchronously.
#    4866
#    4867 Args:
#    (...)   4877
#    4878 """
#    4879 if hasattr(self, "func"):
# -> 4880     return self._call_with_config(
#    4881         self._invoke,
#    4882         input,
#    4883         ensure_config(config),
#    4884         **kwargs,
#    4885     )
#    4886 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4887 raise TypeError(msg)
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:435, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     433 if run_manager is not None and accepts_run_manager(func):
#     434     kwargs["run_manager"] = run_manager
# --> 435 return func(input, **kwargs)
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:4737, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4735                 output = chunk
#    4736 else:
# -> 4737     output = call_func_with_variable_args(
#    4738         self.func, input_, config, run_manager, **kwargs
#    4739     )
#    4740 # If the output is a Runnable, invoke it
#    4741 if isinstance(output, Runnable):
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/.venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:435, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     433 if run_manager is not None and accepts_run_manager(func):
#     434     kwargs["run_manager"] = run_manager
# --> 435 return func(input, **kwargs)
#
# File ~/Desktop/personal-project/Langchain/AnshLamber2/.venv/lib/python3.12/site-packages/langchain_core/load/serializable.py:117, in Serializable.__init__(self, *args, **kwargs)
#     115 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     116     """"""  # noqa: D419  # Intentional blank docstring
# --> 117     super().__init__(*args, **kwargs)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given
