# %% [markdown]
# ## Simple Chain (LCEL - LangChain Expression Language)
#   The modern way using | operator:

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os
from load_dotenv import load_dotenv
load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("API KEY VARAIBLE EXIST")
else:
   raise ValueError("OPENAI_API_KEY NOT FOUND") 

chain = (
    ChatPromptTemplate.from_template("Explain {topic} in simple terms")
    | ChatOpenAI(model="gpt-5-mini")
    | StrOutputParser()
)

result = chain.invoke({"topic": "blockchain"})
print(result)
# Out:
# API KEY VARAIBLE EXIST
# Short answer
# A blockchain is a shared, tamper-resistant digital ledger that records transactions in a way that many computers agree on. Once something is added, it’s very hard to change, and everyone with access can see the same history.
#
# Simple analogy
# - Think of a blockchain like a public notebook that everyone can copy. Whenever people agree a page is correct, it’s glued into a binder. Everyone replaces their old notebook with the new glued binder, so all copies stay the same.
#
# How it works (step-by-step, simply)
# 1. Someone creates a transaction (e.g., Alice sends 1 coin to Bob).
# 2. That transaction is broadcast to a network of computers (nodes).
# 3. Nodes check the transaction is valid (Alice has the coin and the signature is correct).
# 4. Valid transactions are grouped into a “block” (like a page in the notebook).
# 5. The network uses a process (consensus) to agree which block is added next. Different systems do this differently (examples: proof-of-work or proof-of-stake).
# 6. Once agreed, the block is added to the end of the chain, and every node updates its copy of the ledger.
# 7. Because each block links to the previous block (with a cryptographic “fingerprint”), changing any past entry would be obvious and very difficult.
#
# Key properties
# - Decentralized: No single company controls the ledger; many participants keep copies.
# - Transparent: Anyone with permission can see the history of transactions.
# - Immutable (hard to change): Blocks link to each other cryptographically, so tampering is difficult.
# - Secure: Cryptography and consensus make fake transactions hard to get accepted.
#
# Common uses
# - Cryptocurrencies (Bitcoin, Ether)
# - Smart contracts (self-executing rules)
# - Supply-chain tracking, digital identity, voting systems (experimental/varies by implementation)
#
# Limitations and cautions
# - Not magically private: public blockchains are visible to everyone; sensitive data should be handled carefully.
# - Irreversible: mistakes or stolen funds can be hard or impossible to reverse.
# - Scalability and speed: many blockchains are slower/less efficient than centralized databases.
# - Energy: some consensus methods (like Bitcoin’s proof-of-work) use lots of electricity.
# - Still a developing technology with legal and security challenges.
#
# If you want, I can:
# - Give a one-paragraph non-technical summary to share with others.
# - Compare public vs. private blockchains.
# - Explain proof-of-work vs. proof-of-stake in simple terms.

# %% [markdown]
# ## Sequential Chain (Multiple Steps)
# ## Chain the output of one LLM call into the next:

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-5-mini", temperature=0)

# Step 1: Generate patient symptoms summary
symptoms_chain = (
    ChatPromptTemplate.from_template(
        "Summarize these symptoms in medical terms: {symptoms}"
    )
    | llm
    | StrOutputParser()
)

# Step 2: Generate treatment recommendation
treatment_chain = (
    ChatPromptTemplate.from_template(
        "Given this medical summary: {summary}, recommend treatment"
    )
    | llm
    | StrOutputParser()
)

# combine chain 
  # ← Step 1: Creates RunnableMap
 # ← Step 2: Pipes its OUTPUT to treatment_chain
full_chain = { "summary": symptoms_chain } | treatment_chain

result = full_chain.invoke({"symptoms":"fever, cough, fatigue for 3 days"})
print(result)
# Out:
# Suggested chart/HPI phrasing (pick/modify as appropriate)
# - Quick note for triage: "3-day history of fever, cough, and generalized fatigue."
# - HPI for chart: "Acute onset (3 days) of fever, cough, and malaise. Patient reports measured fever of 38.3°C at home and a dry cough; denies dyspnea, pleuritic chest pain, or sputum production."
# - Alternative if subjective/productive: "Acute onset (3 days) of subjective fever, productive cough with yellowish sputum, and fatigue."
#
# Key differential (most to least likely)
# - Viral upper respiratory infection (including COVID-19, influenza)
# - Acute bronchitis
# - Community-acquired pneumonia (less likely if no dyspnea, focal exam findings, or hypoxia)
# - Less likely: pertussis, atypical pathogens, noninfectious causes
#
# Recommended initial management (outpatient, clinically stable)
# 1. Symptomatic care
#    - Antipyretic/analgesic: acetaminophen or ibuprofen per product dosing for fever/aches.
#    - Hydration, rest, throat lozenges/saline nasal irrigation.
#    - For cough: honey (if >1 year old) or OTC cough suppressants/expectorants as needed (dextromethorphan, guaifenesin).
# 2. Testing
#    - Consider rapid SARS‑CoV‑2 and influenza testing, especially if within their treatment windows or during high community prevalence.
#    - A chest x‑ray and/or pulse oximetry if any shortness of breath, tachypnea, hypoxia, focal lung findings on exam, or failure to improve/worsening after 48–72 hours.
# 3. Antibiotics
#    - Do not start antibiotics empirically for uncomplicated acute cough without clinical or radiographic evidence of bacterial pneumonia. Consider antibiotics if there are signs of bacterial pneumonia (fever + focal chest findings, hypoxia, marked tachycardia/tachypnea, leukocytosis) or if symptoms worsen/persist.
# 4. Antiviral therapy
#    - If influenza is suspected and within 48 hours (or later for high‑risk patients), consider oseltamivir per clinician decision.
#    - If COVID‑19 positive and patient is at high risk for progression, contact clinician promptly about antiviral options (e.g., nirmatrelvir/ritonavir) — treatment-window and eligibility criteria apply.
# 5. Return precautions / urgent evaluation
#    - Seek immediate care for any new or worsening shortness of breath, chest pain, oxygen saturation <92% (or baseline for COPD patients), confusion, inability to drink/maintain fluids, or syncope.
#    - Reassess if fever persists beyond 48–72 hours or symptoms worsen.
#
# What I need to refine recommendations
# - Was the fever measured or subjective? If measured, what value and how taken?
# - Is the cough dry or productive (color of sputum)?
# - Any shortness of breath, chest pain, or focal lung exam findings?
# - Age, pregnancy status, major comorbidities (COPD, heart disease, diabetes, immunosuppression), allergies, and current medications.
#
# If you want, give me the answers and I’ll provide a tailored treatment plan and suggested chart wording.

# %% [markdown]
# ##  Router Chain (Conditional Logic)
# ## Route to different chains based on input:

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")

# Different chains for different departments
pediatric_chain = (
    ChatPromptTemplate.from_template("Pediatric advice for: {query}")
    | llm
    | StrOutputParser()
)

adult_chain = (
    ChatPromptTemplate.from_template("Adult care advice for: {query}")
    | llm
    | StrOutputParser()
)

# Router logic
def route_by_age(input_data):
    if input_data["age"] < 18:
        return pediatric_chain
    return adult_chain

# Use it
chain = route_by_age({"age": 25, "query": "HIV treatment"})
result = chain.invoke({"query": "HIV treatment options"})
print(result)
# Out:
# Brief overview
# - Goal of HIV treatment: suppress plasma HIV RNA to “undetectable” and keep it there (prevents disease progression and stops sexual transmission).
# - Recommendation: start antiretroviral therapy (ART) for all people with HIV as soon as possible after diagnosis (same‑day start often appropriate) unless there is a clear reason to delay.
# - Choice of regimen is individualized by prior ART exposure, baseline viral load, CD4 count, resistance test results, coinfections (HBV, TB), pregnancy or pregnancy potential, drug interactions, kidney/hepatic function, and patient preference.
#
# Baseline tests before or at ART start
# - HIV RNA (viral load) and CD4 count
# - HIV genotype (resistance) test if possible (guides regimen choice)
# - Hepatitis B surface antigen, hepatitis B surface antibody, hepatitis C antibody/RNA
# - HLA‑B*5701 (if abacavir is considered)
# - Pregnancy test for people who can be pregnant
# - Renal function (creatinine, eGFR), liver tests, fasting lipids and glucose
# - STI screening and baseline vaccinations as indicated
#
# Preferred first‑line options (commonly used)
# - An INSTI‑based single‑tablet regimen is preferred for most adults because of potency, tolerability and high barrier to resistance:
#   - Bictegravir/tenofovir alafenamide/emtricitabine (Biktarvy) — widely used first line
#   - Dolutegravir + tenofovir alafenamide or tenofovir disoproxil fumarate + lamivudine or emtricitabine (examples: Tivicay + Descovy/Truvada; or Triumeq if abacavir eligible)
# - Dual‑therapy option in selected treatment‑naïve patients:
#   - Dolutegravir + lamivudine (Dovato) — for people without HBV coinfection and when resistance tests/clinical situation allow
# - Long‑acting injectable maintenance (for patients already virologically suppressed and meeting criteria):
#   - Intramuscular cabotegravir + rilpivirine (Cabenuva) every 4 or 8 weeks
#
# Key considerations and special situations
# - HLA‑B*5701 positive → avoid abacavir-containing regimens (risk of hypersensitivity).
# - HBV coinfection → use a regimen active against HBV (tenofovir + lamivudine or emtricitabine as part of ART).
# - Pregnancy or trying to conceive → current guidance supports dolutegravir‑based regimens at any time in pregnancy; tenofovir disoproxil fumarate (TDF) + emtricitabine/lamivudine is commonly used. Discuss risks/benefits with obstetric and HIV clinicians.
# - Tuberculosis (rifampin) → many interactions with ART (rifampin can reduce levels of most INSTIs and NNRTIs); dosing adjustments or alternate agents may be needed; coordinate HIV–TB treatment closely.
# - Renal impairment → TAF preferred over TDF in people with reduced renal function (but check eGFR thresholds); some agents require dose modification or avoidance.
# - Drug–drug interactions → check interactions with common drugs (statins, anticonvulsants, rifamycins, acid suppressants, hormonal contraception). Use an interaction checker or consult a pharmacist.
#
# When resistance or treatment‑experience limits options
# - For people with virologic failure or multi‑drug resistance, regimens are chosen based on resistance testing. Options may include:
#   - Boosted protease inhibitor‑based regimens (darunavir + ritonavir/cobicistat) combined with active NRTIs or novel agents
#   - Newer agents for heavily treatment‑experienced patients: fostemsavir, ibalizumab, lenacapavir (use under specialist care)
# - Always involve an HIV specialist for salvage therapy planning.
#
# Monitoring after starting ART
# - Viral load: check ~2–4 weeks after start if possible, then at 4–8 weeks and every 3 months until suppressed; once suppressed, every 3–6 months.
# - CD4: baseline and repeated as indicated (every 3 months until stable and then less often if >200).
# - Renal and liver function, lipids, glucose periodically based on the regimen and comorbidities.
# - Adherence assessment and adverse effects monitoring at each visit.
#
# Prevention and supportive care
# - Ongoing counseling about adherence, safer sex, and partner notification/testing.
# - Vaccinations per schedule (influenza, pneumococcus, hepatitis A/B if susceptible, HPV, Tdap).
# - Prophylaxis for opportunistic infections (e.g., TMP‑SMX for PCP when CD4 <200; toxoplasmosis prophylaxis when IgG+ and CD4 <100; MAC prophylaxis rarely needed if ART started promptly).
# - Offer partner services and consider PrEP for HIV‑negative partners.
#
# Practical points for patients
# - Take ART exactly as prescribed — missing doses increases risk of resistance.
# - Expect possible early side effects (nausea, headache, sleep changes) that often improve; report severe or persistent problems.
# - If you have other medications or supplements, check for interactions before changing anything.
# - Keep follow‑up appointments and lab monitoring.
#
# When to seek urgent care
# - New neurologic symptoms, severe abdominal pain, jaundice, signs of severe allergic reaction (rash, fever, facial swelling), or symptoms of opportunistic infections — seek immediate medical attention.
#
# Next steps
# - If you or someone you care for has newly diagnosed HIV, arrange linkage to an HIV clinic or provider ASAP for baseline testing and to begin ART (same‑day start when feasible).
# - If you’d like, tell me some specifics (current diagnosis date, prior ART, other medical problems, pregnancy, coinfections, current meds) and I can outline regimen options more tailored to that situation.
#
# Note: This is general information and not a substitute for medical care. Consult an HIV clinician for individualized treatment decisions.

# %% [markdown]
# ## Router Chain (Conditional Logic)
# ### Route to different chains based on input

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini", temperature=0)

pediatric_Chain = (
    ChatPromptTemplate.from_template("Pediatric advise for: {query} ")
    | llm | StrOutputParser())


adult_Chain = (ChatPromptTemplate.from_template("Adult care advise for: {query} ") 
 | llm | StrOutputParser())

def route_by_age(input_data): 
    if input_data["age"] > 18:
       return adult_Chain
    return pediatric_Chain

chain = route_by_age({"age": 25, "query": "HIV treatment"})
result = chain.invoke({"query": "HIV treatment options"})
print(result)

# %% [markdown]
# ## Example: Patient Assessment Chain

# %%
from langchain_core.output_parsers import StrOutputParser
from pydantic import Field
from pydantic import BaseModel
from langchain_openai import ChatOpenAI


class TreatmentRecommendation(BaseModel):
    recommendation: str = Field(description="Treatment recommendation")
    urgency: str = Field(description="low, medium, or high")
    follow_up_days: int = Field(description="Days until follow-up")
    notes: str = Field(description="Additional clinical notes")



analysis_chain = (
    ChatPromptTemplate.from_template("""
    Analyze this HIV patient data:
    
    Patient ID: {patient_id}
    CD4 Count: {cd4_count}
    Viral Load: {viral_load}
    Current Regimen: {regimen}
    Adherence: {adherence}
    
    Provide a clinical assessment.
    """)
    | llm
    | StrOutputParser()
)

# Step 2: Generate structured recommendation
recommendation_chain = (
    ChatPromptTemplate.from_template("""
    Based on this assessment: {assessment}
    
    Provide treatment recommendation in JSON format:
    {{
        "recommendation": "specific action to take",
        "urgency": "low/medium/high",
        "follow_up_days": number,
        "notes": "additional notes"
    }}
    """)
    | llm
    | JsonOutputParser(pydantic_object=TreatmentRecommendation)
)


full_assessment_chain = {
     {
        "assessment": analysis_chain,
        "patient_id": lambda x: x["patient_id"]
    }
} | recommendation_chain

patient_data = {
    "patient_id": "LAM12345",
    "cd4_count": 180,
    "viral_load": 75000,
    "regimen": "TDF/3TC/EFV",
    "adherence": "Good"
}

result = full_assessment_chain.invoke(patient_data)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 3
#       1 from langchain_core.output_parsers import StrOutputParser
#       2 from pydantic import Field
# ----> 3 from tables import Description
#       4 from pydantic import BaseModel
#       5 from langchain_openai import ChatOpenAI
#
# ModuleNotFoundError: No module named 'tables'
